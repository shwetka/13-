# %% [markdown]
# Фермер хочет узнать количество овец и уток, которые у него есть. Он насчитал
# всего 40 (х) голов и 124 (y) ноги. Сколько у него овец и сколько уток ?
#
# Напишите сколько и кого, подумайте над формулой по которой можно посчитать. Продумайте, какие могут быть краевые случаи и как проверить на ошибки. Помните, что у овец 4 ноги, а у уток 2, т.е нужно исключить неправильный вариант ввода. Пишите ответы и соображения

# %% [markdown]
# Сделайте ввод данных с клавиатуры, и вывод на экран

# %%
print ("Напишие количество всех голов")
x=int (input())
print ("Напищите количество всех ног")
y=int (input())
number_sheeps=(y-2*x)/(2)
number_duck=x-number_sheeps
print (number_sheeps)
print (number_duck)

# %% [markdown]
# Сделате проверку, какое минимальное количество ног может быть, и какое максимальное, в случае ошибки сообщите об этом пользователю

# %%
rint ("Напишие количество всех голов")
x=int (input())
print ("Напищите количество всех ног")
y=int (input())
if y<=x*2:
    print("слишком мало ног")
elif y>=x*4:
    print("слишком много ног")
elif y%(2)!=0:
    print ("Это невозможно")
else:
    number_sheeps=(y-2*x)/(2)
    number_duck=x-number_sheeps
    print (number_sheeps)
    print (number_duck)

# %% [markdown]
# Теперь предствьте, чо вместо фермера у вас теперь мальчик Вася, который собирает из Лего монстров. У него есть монстры двух типов,   с числом рук a, и с числом рук b. Измените формулы, не забывайте именить формулы проверки.
# ![15533419950_c09117d71b_b.jpg](attachment:15533419950_c09117d71b_b.jpg)

# %%
print ("Напишие количество всех голов")
x=int (input())
print ("Напищите количество всех ног")
y=int (input())
print ("Напишите количество ног у животного с меньшим количеством ног")
a=int (input())
print ("Напишите количество ног у животного с большим количеством ног")
b=int (input())


if y<=x*a:
    print("слишком мало ног")
elif y>=x*b:
    print("слишком много ног")
elif y%(b-a)!=0:
    print ("Это невозможно")
else:
    number_sheeps=(y-a*x)/(b-a)
    number_duck=x-number_sheeps
    print (number_sheeps)
    print (number_duck)
# Out:
# Напишие количество всех голов
# 24
# Напищите количество всех ног
# 50
# Напишите количество ног у животного с меньшим количеством ног
# 1
# Напишите количество ног у животного с большим количеством ног
# 3
# 13.0
# 11.0
